# %%
from nilmtk.api import API
import warnings
warnings.filterwarnings("ignore")

# %%
from nilmtk.disaggregate import CO,Hart85,FHMMExact,Disaggregator,Mean

# %%
from sklearn.metrics import r2_score

experiment = {
    'power': {'mains': ['apparent', 'active'], 'appliance': ['apparent', 'active']},
    'sample_rate': 60,
    'appliances': ['fridge', 'sockets', 'dish washer','light','washer dryer'],
    'methods': {"hart85":Hart85({}), "CO": CO({})},
    'train': {
        'datasets': {
            'Dataport': {
                'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
                'buildings': {
                    1: {
                        'start_time': '2011-04-18',
                        'end_time': '2011-05-15'
                    }
                }
            }
        }
    },
    'test': {
        'datasets': {
            'Dataport': {
                'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
                'buildings': {
                    1: {
                        'start_time': '2011-05-16',
                        'end_time': '2011-05-24'
                    }
                }
            }
        },
        'metrics': ['rmse', 'mae', 'rmae', 'mse']
    }
}

# %%
api2 = API(experiment)
api2.experiment()
# Out:
# Joint Testing for all algorithms
# Loading data for  Dataport  dataset
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=20, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Generating predictions for : Hart85
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# Generating predictions for : Hart85 dryer'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# ...

# %%
experiment3 = {
  'power': {'mains': ['apparent','active'],'appliance': ['apparent','active']},
  'sample_rate': 60,
  'appliances': ['fridge','microwave'],
  'artificial_aggregate': True,
  'chunksize': 20000,
  'DROP_ALL_NANS': True,
  'methods': {"Mean":Mean({}), "CO":CO({})},
  'train': {    
    'datasets': {
      'Dataport': {
        'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
                }                
            }
        }
    },
  'test': {
    'datasets': {
      'Datport': {
         'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
        }
      }
    },
        'metrics':['mae', 'rmse']
    }
}

# %%
api3 = API(experiment3)
api3.experiment()
# Out:
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Creating an Artificial Aggregate
# Generating predictions for : Mean
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# Generating predictions for : Meanowave'
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# ............  mae  ..............owave'
#                 Mean         CO
# fridge     77.973801  15.083731
# microwave  22.805429   9.360523
# ............  rmse  ..............
#                  Mean         CO
# fridge      84.890290  30.316223
# microwave  116.676657  37.388904
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Creating an Artificial Aggregate
# ...

# %%
from nilmtk.disaggregate import Hart85
experiment4 = {
  'power': {'mains': ['apparent','active'],'appliance': ['apparent','active']},
  'sample_rate': 60,
  'appliances': ['fridge','microwave'],
  'artificial_aggregate': True,
  'chunksize': 20000,
  'DROP_ALL_NANS': True,
  'methods': {"hart85":Hart85({}), "CO":CO({})},
  'train': {    
    'datasets': {
      'Dataport': {
        'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
                }                
            }
        }
    },
  'test': {
    'datasets': {
      'Datport': {
         'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
        }
      }
    },
        'metrics':['mae', 'rmse']
    }
}

# %%
api4 = API(experiment4)
api4.experiment()
# Out:
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Creating an Artificial Aggregate
# Generating predictions for : Hart85
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# Generating predictions for : Hart85ave'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# ............  mae  ..............owave'
#               hart85         CO
# ...

# %%
from nilmtk.nilmtk.disaggregate import FHMMExact
experiment5 = {
  'power': {'mains': ['apparent','active'],'appliance': ['apparent','active']},
  'sample_rate': 60,
  'appliances': ['fridge','microwave'],
  'artificial_aggregate': True,
  'chunksize': 20000,
  'DROP_ALL_NANS': True,
  'methods': {"FHMM_EXACT":FHMMExact({'num_of_states':2}), "CO":CO({})},
  'train': {    
    'datasets': {
      'Dataport': {
        'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
                }                
            }
        }
    },
  'test': {
    'datasets': {
      'Datport': {
         'path': '/Users/evangelosgeraridis/Desktop/redd.h5',
        'buildings': {
          1: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          2: {
            'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
          3: {
           'start_time': '2011-04-28',
            'end_time': '2011-05-05'
          },
        }
      }
    },
        'metrics':['mae', 'rmse']
    }
}

# %%
api5 = API(experiment5)
api5.experiment()
# Out:
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Loading data for meter ElecMeterID(instance=2, building=1, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Creating an Artificial Aggregate
# Generating predictions for : FHMM
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# Generating predictions for : FHMMowave'
# Generating predictions for : CO
# ...............CO disaggregate_chunk running.............
# ............  mae  ..............owave'
#            FHMM_EXACT         CO
# fridge      12.957874  14.862224
# microwave   10.637766   8.997166
# ............  rmse  ..............
#            FHMM_EXACT         CO
# fridge      32.843573  29.815094
# microwave   94.184566  36.953906
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Creating an Artificial Aggregate
# ...
